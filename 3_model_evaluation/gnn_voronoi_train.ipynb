# %%
import os
import sys
sys.path.append(os.getcwd())
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")) + '/lib/')
import time
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
from torch_geometric.data import DataLoader
from lib.net import GNN_Net
from lib.pytorchtools import EarlyStopping, check_gpu

# %% [markdown]
# ## 1. Define Main Loop for GNN Training

# %%
def main(train_data_dir):

    ####  1. Training Parameter Setting  ####

    LR = 0.0015  ## learning rate

    epoch_num = 200  ## epoch number

    batch_size = 512  ## batch size

    patience = 30  ## early_stopping patience

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  ## device defination

    model = GNN_Net().to(device)  ## GNN model loading

    optimizer = torch.optim.Adam(model.parameters(), lr=LR)  ## optimizer setting

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True,
                                                           threshold=0.001, threshold_mode='rel',
                                                           cooldown=0, min_lr=0, eps=1e-08)  ## learning rate adapter setting

    criterion = nn.L1Loss()  ## MAE Loss

    early_stopping = EarlyStopping(patience=patience, verbose=True)  ## initialize the early_stopping object

    history = {
        "train_loss": [],
        "train_time": [],
        "val_loss": [],
    }  ## training history recording


    ####  2. Dataset Loading  ####

    graph_list_dir = os.path.join(train_data_dir, 'Train_val_data_list.pt')  ## train/val set dir
    graph_list = torch.load(graph_list_dir)  ## load voronoi graph dataset
    np.random.shuffle(graph_list)  ## shuffle the dataset
    np.random.shuffle(graph_list)  ## shuffle the dataset

    train_size = int(len(graph_list) * 0.8)   ## train set size
    val_size = int(len(graph_list) * 0.2)   ## validation set size

    trainset = graph_list[:train_size]  
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, drop_last=True)  ## training dataset

    valset = graph_list[train_size:train_size + val_size]  
    validloader = DataLoader(valset, batch_size=batch_size, shuffle=True, drop_last=True)  ## validation dataset


    ####  3. Start Training   ####
    
    print('Start Train')
    
    erro = 10000  ## initialise error value to max
    pose_2_norm = 1  ## pose_2 norm scale
    pose_6_norm = 1  ## pose_6 norm scale

    for epoch in range(epoch_num):  ## start an epoch...
        
        start = time.time()
        train_loss = 0.0
        train_total = 0
        train_batch_num = 0.0

        ## Train loop
        for i, batch in enumerate(trainloader):  ## start a batch...

            model.train()  ## set as traning mode
            
            batch = batch.to(device)  ## load batch data

            optimizer.zero_grad()  ## gradiant clear

            outputs = model(batch)  ## GNN model prediction output

            out_norm = outputs*torch.tensor([pose_2_norm,pose_6_norm]).cuda() ## output normalization

            label_norm = (batch.t).view(outputs.size())*torch.tensor([pose_2_norm,pose_6_norm]).cuda()  ## target normalization

            loss = criterion(out_norm, label_norm)  ## calculate loss    

            loss.backward()  ## backward

            optimizer.step()  ## parameter update bt optimizer

            train_loss += loss.cpu().item()  ## Loss add

            train_total += 1  ## update train times 

            train_batch_num += 1  ## update batch number 

            if i % 10 == 9:
                progress_bar = '[' + ('=' * ((i + 1) // 10)) + (' ' * ((train_size // 100 - (i + 1)) // 10)) + ']'
                print('\repoch: {:d} training loss: {:.5f} {}'
                      .format(epoch + 1, loss.cpu().item(), progress_bar), end="  ")  ## live Loss

        time_cost = time.time() - start
        
        print('\repoch: {:d} train loss: {:.5f} training time: {:.1f} s/epoch'
              .format(epoch + 1, train_loss / (train_size / batch_size), time_cost), end="  ")  # current epoch avrage Loss of each batch

        history["train_loss"].append(train_loss / (train_size / batch_size))  ## record train loss
        history["train_time"].append(time_cost)   ## record train time cost


        ####  4. Start Validation  ####

        model.eval()  ## set as evaluation mode, to make traning smoother and faster, may just note and ignore it

        val_batch_num = 0
        val_loss = 0
        
        ## Validation loop
        with torch.no_grad():  ## stop gradiant update

            for data in validloader: 

                data = data.to(device)  ## load batch data

                outputs = model(data)  ## GNN model prediction output

                out_norm = outputs*torch.tensor([pose_2_norm, pose_6_norm]).cuda()

                label_norm = (data.t).view(outputs.size())*torch.tensor([pose_2_norm,pose_6_norm]).cuda()

                val_loss += criterion(out_norm, label_norm)  ## Valid Loss

                val_batch_num += 1

        history["val_loss"].append(float(val_loss / val_batch_num))  ## record val loss

        print(f'Valid Loss: {val_loss / val_batch_num:.5f}', end='  ')  ## val loss

        scheduler.step(loss.cpu().item() / val_batch_num)  # learning rate update

        LR_ = optimizer.param_groups[0]['lr']  ## new learning rate

        print('\n' + f'learning rate: {LR_:.8f}', end='  ')  

        if (val_loss / val_batch_num) < erro:  ## save the best model from all epoch

            erro = val_loss / val_batch_num

            model_dir = train_data_dir + '/best_model.pth'

            torch.save(model.state_dict(), model_dir)   

            print('\n' + 'Saving model......' + '\n')
            
        # early_stopping needs the validation loss to check if it has decresed, 
        # and if it has, it will make a checkpoint of the current model
        early_stopping(val_loss, model)
        
        if early_stopping.early_stop:
            print('\n' + 'Early stopping')
            break

    # load the last checkpoint with the best model
    # model.load_state_dict(torch.load('checkpoint.pt'))
    
    print('\n' + 'Finished Training')
    

    ####  5. Save Training Results  ####
    
    ## visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(history["train_loss"])+1),history["train_loss"], label='Training Loss')
    plt.plot(range(1,len(history["val_loss"])+1),history["val_loss"],label='Validation Loss')
    
    ## find position of lowest validation loss
    minposs = history["val_loss"].index(min(history["val_loss"]))+1 
    plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')
    
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0, history["train_loss"][0]*1.2) # consistent scale
    plt.xlim(0, len(history["train_loss"])+1) # consistent scale
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    ## save the loss plot
    fig.savefig(train_data_dir + '/loss_plot' + '.png', bbox_inches='tight')

# %% [markdown]
# ## 2. Run Main Loop for GNN Training

# %%
train_data_dir = r'..\result\train'  ## train data dir

check_gpu(0)  ## set gpu device id

if __name__ == "__main__":
    
    main(train_data_dir)
# Out:
# device_count: 1
# current_device: 0
# device_name: NVIDIA GeForce RTX 3070 Ti Laptop GPU
# device_capability: (8, 6)
# device_properties: _CudaDeviceProperties(name='NVIDIA GeForce RTX 3070 Ti Laptop GPU', major=8, minor=6, total_memory=8191MB, multi_processor_count=46)
# is_available: True
# d:\Anaconda\install\envs\GNN\lib\site-packages\torch_geometric\deprecation.py:12: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Start Train
# epoch: 1 train loss: 4.73639 training time: 3.5 s/epoch  Valid Loss: 5.86331
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (inf --> 5.863315).  Saving model ...
# epoch: 2 train loss: 4.06690 training time: 0.6 s/epoch  Valid Loss: 5.83592
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (5.863315 --> 5.835921).  Saving model ...
# epoch: 3 train loss: 3.69171 training time: 0.6 s/epoch  Valid Loss: 5.84763
# learning rate: 0.00150000  EarlyStopping counter: 1 out of 30
#
# epoch: 4 train loss: 3.38130 training time: 0.6 s/epoch  Valid Loss: 5.71708
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (5.835921 --> 5.717080).  Saving model ...
# epoch: 5 train loss: 3.06647 training time: 0.6 s/epoch  Valid Loss: 5.47307
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (5.717080 --> 5.473072).  Saving model ...
# epoch: 6 train loss: 2.85057 training time: 0.6 s/epoch  Valid Loss: 5.21447
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (5.473072 --> 5.214468).  Saving model ...
# epoch: 7 train loss: 2.64386 training time: 0.6 s/epoch  Valid Loss: 4.96505
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (5.214468 --> 4.965048).  Saving model ...
# epoch: 8 train loss: 2.45782 training time: 0.6 s/epoch  Valid Loss: 4.57382
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (4.965048 --> 4.573818).  Saving model ...
# epoch: 9 train loss: 2.25599 training time: 0.6 s/epoch  Valid Loss: 4.02851
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (4.573818 --> 4.028509).  Saving model ...
# epoch: 10 train loss: 2.02510 training time: 0.6 s/epoch  Valid Loss: 3.47205
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (4.028509 --> 3.472055).  Saving model ...
# epoch: 11 train loss: 1.86105 training time: 0.6 s/epoch  Valid Loss: 2.95901
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (3.472055 --> 2.959012).  Saving model ...
# epoch: 12 train loss: 1.66046 training time: 0.6 s/epoch  Valid Loss: 2.35048
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (2.959012 --> 2.350475).  Saving model ...
# epoch: 13 train loss: 1.45170 training time: 0.6 s/epoch  Valid Loss: 2.00908
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (2.350475 --> 2.009080).  Saving model ...
# epoch: 14 train loss: 1.26432 training time: 0.6 s/epoch  Valid Loss: 1.90383
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (2.009080 --> 1.903833).  Saving model ...
# epoch: 15 train loss: 1.13547 training time: 0.6 s/epoch  Valid Loss: 1.97079
# learning rate: 0.00150000  EarlyStopping counter: 1 out of 30
#
# epoch: 16 train loss: 0.92970 training time: 0.6 s/epoch  Valid Loss: 1.42869
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (1.903833 --> 1.428690).  Saving model ...
# epoch: 17 train loss: 0.82657 training time: 0.6 s/epoch  Valid Loss: 1.42518
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (1.428690 --> 1.425179).  Saving model ...
# epoch: 18 train loss: 0.75570 training time: 0.6 s/epoch  Valid Loss: 1.08507
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (1.425179 --> 1.085065).  Saving model ...
# epoch: 19 train loss: 0.70234 training time: 0.6 s/epoch  Valid Loss: 2.02723
# learning rate: 0.00150000  EarlyStopping counter: 1 out of 30
#
# epoch: 20 train loss: 0.67731 training time: 0.6 s/epoch  Valid Loss: 1.98724
# learning rate: 0.00150000  EarlyStopping counter: 2 out of 30
#
# epoch: 21 train loss: 0.66997 training time: 0.6 s/epoch  Valid Loss: 1.05485
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (1.085065 --> 1.054847).  Saving model ...
# epoch: 22 train loss: 0.62018 training time: 0.6 s/epoch  Valid Loss: 0.77425
# learning rate: 0.00150000
# Saving model......
#
# Validation loss decreased (1.054847 --> 0.774251).  Saving model ...
# epoch: 23 train loss: 0.61663 training time: 0.6 s/epoch  Valid Loss: 0.79987  Epoch 00023: reducing learning rate of group 0 to 7.5000e-04.
#
# learning rate: 0.00075000  EarlyStopping counter: 1 out of 30
#
# epoch: 24 train loss: 0.63221 training time: 0.6 s/epoch  Valid Loss: 0.77296
# learning rate: 0.00075000
# Saving model......
#
# Validation loss decreased (0.774251 --> 0.772965).  Saving model ...
# epoch: 25 train loss: 0.56983 training time: 0.6 s/epoch  Valid Loss: 0.94196
# learning rate: 0.00075000  EarlyStopping counter: 1 out of 30
#
# epoch: 26 train loss: 0.65340 training time: 0.5 s/epoch  Valid Loss: 0.69235
# learning rate: 0.00075000
# Saving model......
#
# Validation loss decreased (0.772965 --> 0.692355).  Saving model ...
# epoch: 27 train loss: 0.57827 training time: 0.6 s/epoch  Valid Loss: 0.87302
# learning rate: 0.00075000  EarlyStopping counter: 1 out of 30
#
# epoch: 28 train loss: 0.62485 training time: 0.6 s/epoch  Valid Loss: 0.76508
# learning rate: 0.00075000  EarlyStopping counter: 2 out of 30
#
# epoch: 29 train loss: 0.57809 training time: 0.6 s/epoch  Valid Loss: 0.75761
# learning rate: 0.00075000  EarlyStopping counter: 3 out of 30
#
# epoch: 30 train loss: 0.59692 training time: 0.6 s/epoch  Valid Loss: 0.69876
# learning rate: 0.00075000  EarlyStopping counter: 4 out of 30
#
# epoch: 31 train loss: 0.61917 training time: 0.6 s/epoch  Valid Loss: 0.63544
# learning rate: 0.00075000
# Saving model......
#
# Validation loss decreased (0.692355 --> 0.635436).  Saving model ...
# epoch: 32 train loss: 0.58591 training time: 0.6 s/epoch  Valid Loss: 0.61502
# learning rate: 0.00075000
# Saving model......
#
# Validation loss decreased (0.635436 --> 0.615023).  Saving model ...
# epoch: 33 train loss: 0.61122 training time: 0.6 s/epoch  Valid Loss: 0.87464
# learning rate: 0.00075000  EarlyStopping counter: 1 out of 30
#
# epoch: 34 train loss: 0.58795 training time: 0.6 s/epoch  Valid Loss: 0.72361  Epoch 00034: reducing learning rate of group 0 to 3.7500e-04.
#
# learning rate: 0.00037500  EarlyStopping counter: 2 out of 30
#
# epoch: 35 train loss: 0.58125 training time: 0.6 s/epoch  Valid Loss: 0.80937
# learning rate: 0.00037500  EarlyStopping counter: 3 out of 30
#
# epoch: 36 train loss: 0.60873 training time: 0.6 s/epoch  Valid Loss: 0.75432
# learning rate: 0.00037500  EarlyStopping counter: 4 out of 30
#
# epoch: 37 train loss: 0.57986 training time: 0.6 s/epoch  Valid Loss: 0.66619
# learning rate: 0.00037500  EarlyStopping counter: 5 out of 30
#
# epoch: 38 train loss: 0.56173 training time: 0.6 s/epoch  Valid Loss: 0.66417  Epoch 00038: reducing learning rate of group 0 to 1.8750e-04.
#
# learning rate: 0.00018750  EarlyStopping counter: 6 out of 30
#
# epoch: 39 train loss: 0.56684 training time: 0.6 s/epoch  Valid Loss: 0.61803
# learning rate: 0.00018750  EarlyStopping counter: 7 out of 30
#
# epoch: 40 train loss: 0.53393 training time: 0.6 s/epoch  Valid Loss: 0.58596
# learning rate: 0.00018750
# Saving model......
#
# Validation loss decreased (0.615023 --> 0.585959).  Saving model ...
# epoch: 41 train loss: 0.55001 training time: 0.6 s/epoch  Valid Loss: 0.55511
# learning rate: 0.00018750
# Saving model......
#
# Validation loss decreased (0.585959 --> 0.555106).  Saving model ...
# epoch: 42 train loss: 0.53979 training time: 0.6 s/epoch  Valid Loss: 0.61165
# learning rate: 0.00018750  EarlyStopping counter: 1 out of 30
#
# epoch: 43 train loss: 0.60431 training time: 0.6 s/epoch  Valid Loss: 0.57983  Epoch 00043: reducing learning rate of group 0 to 9.3750e-05.
#
# learning rate: 0.00009375  EarlyStopping counter: 2 out of 30
#
# epoch: 44 train loss: 0.53880 training time: 0.6 s/epoch  Valid Loss: 0.56554
# learning rate: 0.00009375  EarlyStopping counter: 3 out of 30
#
# epoch: 45 train loss: 0.59420 training time: 0.6 s/epoch  Valid Loss: 0.58516
# learning rate: 0.00009375  EarlyStopping counter: 4 out of 30
#
# epoch: 46 train loss: 0.53248 training time: 0.6 s/epoch  Valid Loss: 0.57336
# learning rate: 0.00009375  EarlyStopping counter: 5 out of 30
#
# epoch: 47 train loss: 0.58409 training time: 0.6 s/epoch  Valid Loss: 0.58759  Epoch 00047: reducing learning rate of group 0 to 4.6875e-05.
#
# learning rate: 0.00004688  EarlyStopping counter: 6 out of 30
#
# epoch: 48 train loss: 0.56648 training time: 0.6 s/epoch  Valid Loss: 0.57968
# learning rate: 0.00004688  EarlyStopping counter: 7 out of 30
#
# epoch: 49 train loss: 0.54177 training time: 0.6 s/epoch  Valid Loss: 0.59639
# learning rate: 0.00004688  EarlyStopping counter: 8 out of 30
#
# epoch: 50 train loss: 0.54878 training time: 0.6 s/epoch  Valid Loss: 0.57594
# learning rate: 0.00004688  EarlyStopping counter: 9 out of 30
#
# epoch: 51 train loss: 0.56806 training time: 0.6 s/epoch  Valid Loss: 0.56203
# learning rate: 0.00004688  EarlyStopping counter: 10 out of 30
#
# epoch: 52 train loss: 0.51510 training time: 0.6 s/epoch  Valid Loss: 0.57406
# learning rate: 0.00004688  EarlyStopping counter: 11 out of 30
#
# epoch: 53 train loss: 0.57333 training time: 0.6 s/epoch  Valid Loss: 0.57156
# learning rate: 0.00004688  EarlyStopping counter: 12 out of 30
#
# epoch: 54 train loss: 0.55220 training time: 0.6 s/epoch  Valid Loss: 0.54748  Epoch 00054: reducing learning rate of group 0 to 2.3438e-05.
#
# learning rate: 0.00002344
# Saving model......
#
# Validation loss decreased (0.555106 --> 0.547481).  Saving model ...
# epoch: 55 train loss: 0.57443 training time: 0.6 s/epoch  Valid Loss: 0.57720
# learning rate: 0.00002344  EarlyStopping counter: 1 out of 30
#
# epoch: 56 train loss: 0.53167 training time: 0.5 s/epoch  Valid Loss: 0.56113
# learning rate: 0.00002344  EarlyStopping counter: 2 out of 30
#
# epoch: 57 train loss: 0.56053 training time: 0.5 s/epoch  Valid Loss: 0.56486
# learning rate: 0.00002344  EarlyStopping counter: 3 out of 30
#
# epoch: 58 train loss: 0.56919 training time: 0.5 s/epoch  Valid Loss: 0.57713  Epoch 00058: reducing learning rate of group 0 to 1.1719e-05.
#
# learning rate: 0.00001172  EarlyStopping counter: 4 out of 30
#
# epoch: 59 train loss: 0.53624 training time: 0.5 s/epoch  Valid Loss: 0.58099
# learning rate: 0.00001172  EarlyStopping counter: 5 out of 30
#
# epoch: 60 train loss: 0.55237 training time: 0.6 s/epoch  Valid Loss: 0.57004
# learning rate: 0.00001172  EarlyStopping counter: 6 out of 30
#
# epoch: 61 train loss: 0.53650 training time: 0.6 s/epoch  Valid Loss: 0.59230
# learning rate: 0.00001172  EarlyStopping counter: 7 out of 30
#
# epoch: 62 train loss: 0.53850 training time: 0.6 s/epoch  Valid Loss: 0.55297  Epoch 00062: reducing learning rate of group 0 to 5.8594e-06.
#
# learning rate: 0.00000586  EarlyStopping counter: 8 out of 30
#
# epoch: 63 train loss: 0.56060 training time: 0.6 s/epoch  Valid Loss: 0.58212
# learning rate: 0.00000586  EarlyStopping counter: 9 out of 30
#
# epoch: 64 train loss: 0.53982 training time: 0.6 s/epoch  Valid Loss: 0.56056
# learning rate: 0.00000586  EarlyStopping counter: 10 out of 30
#
# epoch: 65 train loss: 0.52696 training time: 0.6 s/epoch  Valid Loss: 0.58336
# learning rate: 0.00000586  EarlyStopping counter: 11 out of 30
#
# epoch: 66 train loss: 0.53917 training time: 0.6 s/epoch  Valid Loss: 0.56093  Epoch 00066: reducing learning rate of group 0 to 2.9297e-06.
#
# learning rate: 0.00000293  EarlyStopping counter: 12 out of 30
#
# epoch: 67 train loss: 0.54193 training time: 0.6 s/epoch  Valid Loss: 0.57026
# learning rate: 0.00000293  EarlyStopping counter: 13 out of 30
#
# epoch: 68 train loss: 0.57076 training time: 0.6 s/epoch  Valid Loss: 0.56412
# learning rate: 0.00000293  EarlyStopping counter: 14 out of 30
#
# epoch: 69 train loss: 0.54421 training time: 0.6 s/epoch  Valid Loss: 0.58225
# learning rate: 0.00000293  EarlyStopping counter: 15 out of 30
#
# epoch: 70 train loss: 0.56063 training time: 0.6 s/epoch  Valid Loss: 0.54579  Epoch 00070: reducing learning rate of group 0 to 1.4648e-06.
#
# learning rate: 0.00000146
# Saving model......
#
# Validation loss decreased (0.547481 --> 0.545795).  Saving model ...
# epoch: 71 train loss: 0.59191 training time: 0.6 s/epoch  Valid Loss: 0.58519
# learning rate: 0.00000146  EarlyStopping counter: 1 out of 30
#
# epoch: 72 train loss: 0.53463 training time: 0.6 s/epoch  Valid Loss: 0.55453
# learning rate: 0.00000146  EarlyStopping counter: 2 out of 30
#
# epoch: 73 train loss: 0.55720 training time: 0.6 s/epoch  Valid Loss: 0.58674
# learning rate: 0.00000146  EarlyStopping counter: 3 out of 30
#
# epoch: 74 train loss: 0.54771 training time: 0.6 s/epoch  Valid Loss: 0.58198  Epoch 00074: reducing learning rate of group 0 to 7.3242e-07.
#
# learning rate: 0.00000073  EarlyStopping counter: 4 out of 30
#
# epoch: 75 train loss: 0.53129 training time: 0.6 s/epoch  Valid Loss: 0.58528
# learning rate: 0.00000073  EarlyStopping counter: 5 out of 30
#
# epoch: 76 train loss: 0.54633 training time: 0.6 s/epoch  Valid Loss: 0.55357
# learning rate: 0.00000073  EarlyStopping counter: 6 out of 30
#
# epoch: 77 train loss: 0.54407 training time: 0.6 s/epoch  Valid Loss: 0.56432
# learning rate: 0.00000073  EarlyStopping counter: 7 out of 30
#
# epoch: 78 train loss: 0.53118 training time: 0.5 s/epoch  Valid Loss: 0.55250  Epoch 00078: reducing learning rate of group 0 to 3.6621e-07.
#
# learning rate: 0.00000037  EarlyStopping counter: 8 out of 30
#
# epoch: 79 train loss: 0.55980 training time: 0.6 s/epoch  Valid Loss: 0.60268
# learning rate: 0.00000037  EarlyStopping counter: 9 out of 30
#
# epoch: 80 train loss: 0.57515 training time: 0.6 s/epoch  Valid Loss: 0.54923
# learning rate: 0.00000037  EarlyStopping counter: 10 out of 30
#
# epoch: 81 train loss: 0.56162 training time: 0.6 s/epoch  Valid Loss: 0.58230
# learning rate: 0.00000037  EarlyStopping counter: 11 out of 30
#
# epoch: 82 train loss: 0.54658 training time: 0.6 s/epoch  Valid Loss: 0.55345  Epoch 00082: reducing learning rate of group 0 to 1.8311e-07.
#
# learning rate: 0.00000018  EarlyStopping counter: 12 out of 30
#
# epoch: 83 train loss: 0.58191 training time: 0.6 s/epoch  Valid Loss: 0.57312
# learning rate: 0.00000018  EarlyStopping counter: 13 out of 30
#
# epoch: 84 train loss: 0.57536 training time: 0.6 s/epoch  Valid Loss: 0.54043
# learning rate: 0.00000018
# Saving model......
#
# Validation loss decreased (0.545795 --> 0.540432).  Saving model ...
# epoch: 85 train loss: 0.54332 training time: 0.6 s/epoch  Valid Loss: 0.55748
# learning rate: 0.00000018  EarlyStopping counter: 1 out of 30
#
# epoch: 86 train loss: 0.59579 training time: 0.5 s/epoch  Valid Loss: 0.58300  Epoch 00086: reducing learning rate of group 0 to 9.1553e-08.
#
# learning rate: 0.00000009  EarlyStopping counter: 2 out of 30
#
# epoch: 87 train loss: 0.54137 training time: 0.5 s/epoch  Valid Loss: 0.61103
# learning rate: 0.00000009  EarlyStopping counter: 3 out of 30
#
# epoch: 88 train loss: 0.62054 training time: 0.5 s/epoch  Valid Loss: 0.55362
# learning rate: 0.00000009  EarlyStopping counter: 4 out of 30
#
# epoch: 89 train loss: 0.54154 training time: 0.5 s/epoch  Valid Loss: 0.56751
# learning rate: 0.00000009  EarlyStopping counter: 5 out of 30
#
# epoch: 90 train loss: 0.51439 training time: 0.5 s/epoch  Valid Loss: 0.53716  Epoch 00090: reducing learning rate of group 0 to 4.5776e-08.
#
# learning rate: 0.00000005
# Saving model......
#
# Validation loss decreased (0.540432 --> 0.537158).  Saving model ...
# epoch: 91 train loss: 0.52594 training time: 0.5 s/epoch  Valid Loss: 0.55877
# learning rate: 0.00000005  EarlyStopping counter: 1 out of 30
#
# epoch: 92 train loss: 0.51969 training time: 0.5 s/epoch  Valid Loss: 0.55267
# learning rate: 0.00000005  EarlyStopping counter: 2 out of 30
#
# epoch: 93 train loss: 0.53623 training time: 0.5 s/epoch  Valid Loss: 0.56166
# learning rate: 0.00000005  EarlyStopping counter: 3 out of 30
#
# epoch: 94 train loss: 0.59286 training time: 0.5 s/epoch  Valid Loss: 0.58456  Epoch 00094: reducing learning rate of group 0 to 2.2888e-08.
#
# learning rate: 0.00000002  EarlyStopping counter: 4 out of 30
#
# epoch: 95 train loss: 0.55280 training time: 0.6 s/epoch  Valid Loss: 0.59714
# learning rate: 0.00000002  EarlyStopping counter: 5 out of 30
#
# epoch: 96 train loss: 0.59678 training time: 0.5 s/epoch  Valid Loss: 0.56063
# learning rate: 0.00000002  EarlyStopping counter: 6 out of 30
#
# epoch: 97 train loss: 0.56078 training time: 0.5 s/epoch  Valid Loss: 0.57851
# learning rate: 0.00000002  EarlyStopping counter: 7 out of 30
#
# epoch: 98 train loss: 0.54630 training time: 0.5 s/epoch  Valid Loss: 0.51684  Epoch 00098: reducing learning rate of group 0 to 1.1444e-08.
#
# learning rate: 0.00000001
# Saving model......
#
# Validation loss decreased (0.537158 --> 0.516844).  Saving model ...
# epoch: 99 train loss: 0.61882 training time: 0.5 s/epoch  Valid Loss: 0.58146
# learning rate: 0.00000001  EarlyStopping counter: 1 out of 30
#
# epoch: 100 train loss: 0.56260 training time: 0.5 s/epoch  Valid Loss: 0.57652
# learning rate: 0.00000001  EarlyStopping counter: 2 out of 30
#
# epoch: 101 train loss: 0.55198 training time: 0.5 s/epoch  Valid Loss: 0.57741
# learning rate: 0.00000001  EarlyStopping counter: 3 out of 30
#
# epoch: 102 train loss: 0.59420 training time: 0.5 s/epoch  Valid Loss: 0.55060
# learning rate: 0.00000001  EarlyStopping counter: 4 out of 30
#
# epoch: 103 train loss: 0.58088 training time: 0.5 s/epoch  Valid Loss: 0.56677
# learning rate: 0.00000001  EarlyStopping counter: 5 out of 30
#
# epoch: 104 train loss: 0.56060 training time: 0.5 s/epoch  Valid Loss: 0.56961
# learning rate: 0.00000001  EarlyStopping counter: 6 out of 30
#
# epoch: 105 train loss: 0.57550 training time: 0.5 s/epoch  Valid Loss: 0.58407
# learning rate: 0.00000001  EarlyStopping counter: 7 out of 30
#
# epoch: 106 train loss: 0.54109 training time: 0.5 s/epoch  Valid Loss: 0.59940
# learning rate: 0.00000001  EarlyStopping counter: 8 out of 30
#
# epoch: 107 train loss: 0.56552 training time: 0.5 s/epoch  Valid Loss: 0.56732
# learning rate: 0.00000001  EarlyStopping counter: 9 out of 30
#
# epoch: 108 train loss: 0.55260 training time: 0.5 s/epoch  Valid Loss: 0.57111
# learning rate: 0.00000001  EarlyStopping counter: 10 out of 30
#
# epoch: 109 train loss: 0.55252 training time: 0.5 s/epoch  Valid Loss: 0.56745
# learning rate: 0.00000001  EarlyStopping counter: 11 out of 30
#
# epoch: 110 train loss: 0.56093 training time: 0.5 s/epoch  Valid Loss: 0.55121
# learning rate: 0.00000001  EarlyStopping counter: 12 out of 30
#
# epoch: 111 train loss: 0.52388 training time: 0.5 s/epoch  Valid Loss: 0.57730
# learning rate: 0.00000001  EarlyStopping counter: 13 out of 30
#
# epoch: 112 train loss: 0.57122 training time: 0.5 s/epoch  Valid Loss: 0.57611
# learning rate: 0.00000001  EarlyStopping counter: 14 out of 30
#
# epoch: 113 train loss: 0.55499 training time: 0.6 s/epoch  Valid Loss: 0.59601
# learning rate: 0.00000001  EarlyStopping counter: 15 out of 30
#
# epoch: 114 train loss: 0.53595 training time: 0.5 s/epoch  Valid Loss: 0.56932
# learning rate: 0.00000001  EarlyStopping counter: 16 out of 30
#
# epoch: 115 train loss: 0.52753 training time: 0.5 s/epoch  Valid Loss: 0.57201
# learning rate: 0.00000001  EarlyStopping counter: 17 out of 30
#
# epoch: 116 train loss: 0.57408 training time: 0.5 s/epoch  Valid Loss: 0.56030
# learning rate: 0.00000001  EarlyStopping counter: 18 out of 30
#
# epoch: 117 train loss: 0.53411 training time: 0.5 s/epoch  Valid Loss: 0.57323
# learning rate: 0.00000001  EarlyStopping counter: 19 out of 30
#
# epoch: 118 train loss: 0.55938 training time: 0.5 s/epoch  Valid Loss: 0.58747
# learning rate: 0.00000001  EarlyStopping counter: 20 out of 30
#
# epoch: 119 train loss: 0.54583 training time: 0.5 s/epoch  Valid Loss: 0.59365
# learning rate: 0.00000001  EarlyStopping counter: 21 out of 30
#
# epoch: 120 train loss: 0.55017 training time: 0.5 s/epoch  Valid Loss: 0.60047
# learning rate: 0.00000001  EarlyStopping counter: 22 out of 30
#
# epoch: 121 train loss: 0.55006 training time: 0.5 s/epoch  Valid Loss: 0.55272
# learning rate: 0.00000001  EarlyStopping counter: 23 out of 30
#
# epoch: 122 train loss: 0.62293 training time: 0.5 s/epoch  Valid Loss: 0.56840
# learning rate: 0.00000001  EarlyStopping counter: 24 out of 30
#
# epoch: 123 train loss: 0.52960 training time: 0.5 s/epoch  Valid Loss: 0.52429
# learning rate: 0.00000001  EarlyStopping counter: 25 out of 30
#
# epoch: 124 train loss: 0.55681 training time: 0.5 s/epoch  Valid Loss: 0.54237
# learning rate: 0.00000001  EarlyStopping counter: 26 out of 30
#
# epoch: 125 train loss: 0.58268 training time: 0.5 s/epoch  Valid Loss: 0.56469
# learning rate: 0.00000001  EarlyStopping counter: 27 out of 30
#
# epoch: 126 train loss: 0.56821 training time: 0.5 s/epoch  Valid Loss: 0.58999
# learning rate: 0.00000001  EarlyStopping counter: 28 out of 30
#
# epoch: 127 train loss: 0.56530 training time: 0.5 s/epoch  Valid Loss: 0.56551
# learning rate: 0.00000001  EarlyStopping counter: 29 out of 30
#
# epoch: 128 train loss: 0.61610 training time: 0.5 s/epoch  Valid Loss: 0.59860
# learning rate: 0.00000001  EarlyStopping counter: 30 out of 30
#
#
# Early stopping
#
# Finished Training
